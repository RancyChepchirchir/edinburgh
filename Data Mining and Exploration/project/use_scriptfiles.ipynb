# %%
# %run experiments_alldata.py
# Out:
# C:\Users\Elias\Desktop\MSc Data Science\DME\scripts.py:21: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   X_content_full = X_content_full.convert_objects(convert_numeric=True) # now we can actually convert to numbers
# Dummy accuracy: 0.7774891774891775
# GaussianNB accuracy: 0.7463203463203463
# LogisticRegression accuracy: 0.7783549783549784
# MLPClassifier accuracy: 0.7774891774891775

# %%
(X_content_full, keys_content_features) = read_transform_contentfeatures()
(y_full,keys_labels) = read_transform_labels()
fulldata = join_data(X_content_full, y_full)

# %%
# %run display_2d.py
# Out:
# C:\Users\Elias\Desktop\MSc Data Science\DME\scripts.py:21: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   X_content_full = X_content_full.convert_objects(convert_numeric=True) # now we can actually convert to numbers
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
